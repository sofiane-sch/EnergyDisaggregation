# %%
from EnergyDisaggregation.energydisaggregation.models.nn_model import NeuralNetworkModel, preprocess

# %%
import pandas as pd

# %%
df = pd.read_csv('./EnergyDisaggregation/energydisaggregation/data_storage/df_process.csv')

# %%
df = df[df['Région']=="Provence-Alpes-Côte d'Azur"]

# %%
df.head()
# Out:
#                  Date - Heure                      Région  \
# 10  2013-01-01 00:00:00+01:00  Provence-Alpes-Côte d'Azur
# 22  2013-01-01 01:00:00+01:00  Provence-Alpes-Côte d'Azur
# 34  2013-01-01 02:00:00+01:00  Provence-Alpes-Côte d'Azur
# 46  2013-01-01 03:00:00+01:00  Provence-Alpes-Côte d'Azur
# 58  2013-01-01 04:00:00+01:00  Provence-Alpes-Côte d'Azur
#
#     consommation brute électricité (mw) - rte  température (°c)  \
# 10                                     5570.0         10.225000
# 22                                    11378.0          9.125000
# 34                                    11288.0          4.825000
# 46                                    10682.0          0.525000
# 58                                     9896.0         -2.733333
#
#     nebulosité totale  vitesse du vent moyen 10 mn   humidité  \
# 10          87.500000                         5.10  77.250000
# 22          93.750000                         4.80  76.250000
# 34          68.750000                         3.60  73.250000
# 46          43.750000                         2.40  70.250000
# 58          27.083333                         1.55  68.166667
#
#     vitesse du vent en km/h  température ressentie  saison  ...  \
# 10                    18.36              10.225000       3  ...
# 22                    17.28               6.561446       3  ...
# 34                    12.96               1.870373       3  ...
# 46                     8.64              -2.314499       3  ...
# 58                     5.58              -4.975684       3  ...
#
#     consommation brute électricité (mw) - rte_lag_5  \
# 10                                              NaN
# 22                                              NaN
# 34                                              NaN
# 46                                              NaN
# 58                                              NaN
#
#     consommation brute électricité (mw) - rte_lag_6  \
# 10                                              NaN
# 22                                              NaN
# 34                                              NaN
# 46                                              NaN
# 58                                              NaN
#
#     consommation brute électricité (mw) - rte_lag_7  température (°c)_lag_1  \
# 10                                              NaN                     NaN
# 22                                              NaN               -1.100000
# 34                                              NaN               -4.300000
# 46                                              NaN               -4.300000
# 58                                              NaN               -3.258333
#
#     température (°c)_lag_2  température (°c)_lag_3  température (°c)_lag_4  \
# 10                     NaN                     NaN                     NaN
# 22                     NaN                     NaN                     NaN
# 34               -5.400000                     NaN                     NaN
# 46               -8.600000               -9.700000                     NaN
# 58               -7.558333              -11.858333              -12.958333
#
#    température (°c)_lag_5  température (°c)_lag_6 température (°c)_lag_7
# 10                    NaN                     NaN                    NaN
# 22                    NaN                     NaN                    NaN
# 34                    NaN                     NaN                    NaN
# 46                    NaN                     NaN                    NaN
# 58                    NaN                     NaN                    NaN
#
# [5 rows x 48 columns]

# %%
df_preprocess = preprocess(df)

# %%
df_preprocess.head()
# Out:
#                                                Région  \
# Date - Heure
# 2013-01-01 00:00:00+01:00  Provence-Alpes-Côte d'Azur
# 2013-01-01 01:00:00+01:00  Provence-Alpes-Côte d'Azur
# 2013-01-01 02:00:00+01:00  Provence-Alpes-Côte d'Azur
# 2013-01-01 03:00:00+01:00  Provence-Alpes-Côte d'Azur
# 2013-01-01 04:00:00+01:00  Provence-Alpes-Côte d'Azur
#
#                            consommation brute électricité (mw) - rte  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                                     5570.0
# 2013-01-01 01:00:00+01:00                                    11378.0
# 2013-01-01 02:00:00+01:00                                    11288.0
# 2013-01-01 03:00:00+01:00                                    10682.0
# 2013-01-01 04:00:00+01:00                                     9896.0
#
#                            température (°c)  nebulosité totale  \
# Date - Heure
# 2013-01-01 00:00:00+01:00         10.225000          87.500000
# 2013-01-01 01:00:00+01:00          9.125000          93.750000
# 2013-01-01 02:00:00+01:00          4.825000          68.750000
# 2013-01-01 03:00:00+01:00          0.525000          43.750000
# 2013-01-01 04:00:00+01:00         -2.733333          27.083333
#
#                            vitesse du vent moyen 10 mn   humidité  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                         5.10  77.250000
# 2013-01-01 01:00:00+01:00                         4.80  76.250000
# 2013-01-01 02:00:00+01:00                         3.60  73.250000
# 2013-01-01 03:00:00+01:00                         2.40  70.250000
# 2013-01-01 04:00:00+01:00                         1.55  68.166667
#
#                            vitesse du vent en km/h  température ressentie  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                    18.36              10.225000
# 2013-01-01 01:00:00+01:00                    17.28               6.561446
# 2013-01-01 02:00:00+01:00                    12.96               1.870373
# 2013-01-01 03:00:00+01:00                     8.64              -2.314499
# 2013-01-01 04:00:00+01:00                     5.58              -4.975684
#
#                            saison  week_day  ...  \
# Date - Heure                                 ...
# 2013-01-01 00:00:00+01:00       3         1  ...
# 2013-01-01 01:00:00+01:00       3         1  ...
# 2013-01-01 02:00:00+01:00       3         1  ...
# 2013-01-01 03:00:00+01:00       3         1  ...
# 2013-01-01 04:00:00+01:00       3         1  ...
#
#                            consommation brute électricité (mw) - rte_lag_5  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                                           4174.0
# 2013-01-01 01:00:00+01:00                                           4174.0
# 2013-01-01 02:00:00+01:00                                           4174.0
# 2013-01-01 03:00:00+01:00                                           4174.0
# 2013-01-01 04:00:00+01:00                                           4174.0
#
#                            consommation brute électricité (mw) - rte_lag_6  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                                           3904.0
# 2013-01-01 01:00:00+01:00                                           3904.0
# 2013-01-01 02:00:00+01:00                                           3904.0
# 2013-01-01 03:00:00+01:00                                           3904.0
# 2013-01-01 04:00:00+01:00                                           3904.0
#
#                            consommation brute électricité (mw) - rte_lag_7  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                                           3890.0
# 2013-01-01 01:00:00+01:00                                           3890.0
# 2013-01-01 02:00:00+01:00                                           3890.0
# 2013-01-01 03:00:00+01:00                                           3890.0
# 2013-01-01 04:00:00+01:00                                           3890.0
#
#                            température (°c)_lag_1  température (°c)_lag_2  \
# Date - Heure
# 2013-01-01 00:00:00+01:00               -1.100000               -5.400000
# 2013-01-01 01:00:00+01:00               -1.100000               -5.400000
# 2013-01-01 02:00:00+01:00               -4.300000               -5.400000
# 2013-01-01 03:00:00+01:00               -4.300000               -8.600000
# 2013-01-01 04:00:00+01:00               -3.258333               -7.558333
#
#                            température (°c)_lag_3 température (°c)_lag_4  \
# Date - Heure
# 2013-01-01 00:00:00+01:00               -9.700000             -12.958333
# 2013-01-01 01:00:00+01:00               -9.700000             -12.958333
# 2013-01-01 02:00:00+01:00               -9.700000             -12.958333
# 2013-01-01 03:00:00+01:00               -9.700000             -12.958333
# 2013-01-01 04:00:00+01:00              -11.858333             -12.958333
#
#                            température (°c)_lag_5 température (°c)_lag_6  \
# Date - Heure
# 2013-01-01 00:00:00+01:00              -13.091667                -13.225
# 2013-01-01 01:00:00+01:00              -13.091667                -13.225
# 2013-01-01 02:00:00+01:00              -13.091667                -13.225
# 2013-01-01 03:00:00+01:00              -13.091667                -13.225
# 2013-01-01 04:00:00+01:00              -13.091667                -13.225
#
#                            température (°c)_lag_7
# Date - Heure
# 2013-01-01 00:00:00+01:00              -12.216667
# 2013-01-01 01:00:00+01:00              -12.216667
# 2013-01-01 02:00:00+01:00              -12.216667
# 2013-01-01 03:00:00+01:00              -12.216667
# 2013-01-01 04:00:00+01:00              -12.216667
#
# [5 rows x 47 columns]

# %%
df_train = df_preprocess[df_preprocess.index.year <= 2017]
df_test = df_preprocess[df_preprocess.index.year == 2018]

# %%
nn_model = NeuralNetworkModel(hidden_dim=25, output_dim=1, num_layers=5)

# %%
print(nn_model.model)
# Out:
# NN(
#   (temp): ModuleList(
#     (0): Linear(in_features=22, out_features=25, bias=True)
#     (1): Linear(in_features=25, out_features=25, bias=True)
#     (2): Linear(in_features=25, out_features=25, bias=True)
#     (3): Linear(in_features=25, out_features=25, bias=True)
#     (4): Linear(in_features=25, out_features=1, bias=True)
#   )
#   (calendar): ModuleList(
#     (0): Linear(in_features=10, out_features=25, bias=True)
#     (1): Linear(in_features=25, out_features=25, bias=True)
#     (2): Linear(in_features=25, out_features=25, bias=True)
#     (3): Linear(in_features=25, out_features=25, bias=True)
#     (4): Linear(in_features=25, out_features=1, bias=True)
#   )
# )

# %%
nn_model.fit(df_train)
# Out:
# Starting epoch 1
# Loss after mini-batch     1: 184967.936
# Loss after mini-batch    11: 1851572.880
# Loss after mini-batch    21: 1864372.384
# Loss after mini-batch    31: 1852526.528
# Loss after mini-batch    41: 1860599.824
# Starting epoch 2
# Loss after mini-batch     1: 184286.944
# Loss after mini-batch    11: 1840230.032
# Loss after mini-batch    21: 1824748.224
# Loss after mini-batch    31: 1778225.408
# Loss after mini-batch    41: 1664348.512
# Starting epoch 3
# Loss after mini-batch     1: 153801.808
# Loss after mini-batch    11: 1419831.896
# Loss after mini-batch    21: 1062623.208
# Loss after mini-batch    31: 634773.212
# Loss after mini-batch    41: 315460.382
# Starting epoch 4
# Loss after mini-batch     1: 28041.540
# Loss after mini-batch    11: 275936.548
# Loss after mini-batch    21: 251231.730
# Loss after mini-batch    31: 238995.032
# Loss after mini-batch    41: 236904.616
# Starting epoch 5
# Loss after mini-batch     1: 22418.502
# Loss after mini-batch    11: 225845.584
# Loss after mini-batch    21: 218068.268
# Loss after mini-batch    31: 214438.480
# Loss after mini-batch    41: 213629.466
# Training process has finished.

# %%
a, b, c = nn_model.predict(df_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a, label='Consommation prédite')
plt.plot(b, label='Conso Thermosensible')
plt.plot(c, label='Consommation régulière')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
nn_model.score(df_test['consommation brute électricité (mw) - rte'], a)
# Out:
# 9149762.117351444

# %%
nn_model.save('fichier_test.sav')
# Out:
# Model saved to ../data_storage/fichier_test.sav

# %%
nn_model.load('fichier_test.sav')
# Out:
# Model loaded from ../data_storage/fichier_test.sav
# NN(
#   (temp): ModuleList(
#     (0): Linear(in_features=22, out_features=25, bias=True)
#     (1): Linear(in_features=25, out_features=25, bias=True)
#     (2): Linear(in_features=25, out_features=25, bias=True)
#     (3): Linear(in_features=25, out_features=25, bias=True)
#     (4): Linear(in_features=25, out_features=1, bias=True)
#   )
#   (calendar): ModuleList(
#     (0): Linear(in_features=10, out_features=25, bias=True)
#     (1): Linear(in_features=25, out_features=25, bias=True)
#     (2): Linear(in_features=25, out_features=25, bias=True)
#     (3): Linear(in_features=25, out_features=25, bias=True)
#     (4): Linear(in_features=25, out_features=1, bias=True)
#   )
# )

# %%
nn_model.score(df_test['consommation brute électricité (mw) - rte'], a)
# Out:
# 9149762.117351444

# %%
X_2018 = df_test
X_2018["conso_therm"] = a
X_2018["conso_reg"] = c
X_2018["conso_pred"] = a
# Out:
# /tmp/ipykernel_576699/38118748.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_576699/38118748.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_576699/38118748.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import plotly.express as px
px.line(X_2018[['conso_pred', 'conso_reg', 'conso_therm']])
