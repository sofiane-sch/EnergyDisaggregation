# %%
from EnergyDisaggregation.energydisaggregation.dataloader.config import DATACONFIG, CONFIG_WEATHER, CONFIG_POWER
from EnergyDisaggregation.energydisaggregation.feature_engineering.utils import get_dataframe
import pandas as pd
import warnings
pd.options.plotting.backend = "plotly"
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df_process = get_dataframe()

# %%
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 30672 entries, (Timestamp('2013-01-01 00:00:00+0100', tz='tzoffset(None, 3600)'), 'Auvergne-Rhône-Alpes') to (Timestamp('2019-12-31 00:00:00+0100', tz='tzoffset(None, 3600)'), 'Île-de-France')
# Data columns (total 39 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Consommation brute électricité (MW) - RTE  30672 non-null  float64
#  1   Température (°C)                           30672 non-null  float64
#  2   Nebulosité totale                          30672 non-null  float64
#  3   Vitesse du vent moyen 10 mn                30672 non-null  float64
#  4   Humidité                                   30672 non-null  float64
#  5   Vitesse du vent en km/h                    30672 non-null  float64
#  6   Température ressentie                      30672 non-null  float64
#  7   Vitesse du vent en km/h                    30672 non-null  float64
#  8   Température ressentie                      30672 non-null  float64
#  9   saison                                     30672 non-null  object
#  10  week_day                                   30672 non-null  int64
#  11  month                                      30672 non-null  int64
#  12  is_holiday                                 30672 non-null  bool
#  13  is_bank_holiday                            30672 non-null  bool
#  14  Vitesse du vent en km/h                    30672 non-null  float64
#  15  Température ressentie                      30672 non-null  float64
#  16  years                                      30672 non-null  object
#  17  regions                                    30672 non-null  object
#  18  temperature_seuil                          30672 non-null  float64
#  19  saturation                                 30672 non-null  object
#  20  diff_seuil                                 30672 non-null  float64
#  21  Température ressentie                      30672 non-null  float64
#  22  Température (°C)_mean_48                   30672 non-null  float64
#  23  Température (°C)_std_48                    30672 non-null  float64
#  24  Température (°C)_max_48                    30672 non-null  float64
#  25  Température (°C)_min_48                    30672 non-null  float64
#  26  Nebulosité totale_mean_3                   30672 non-null  float64
#  27  Nebulosité totale_std_3                    30672 non-null  float64
#  28  month_sin                                  30672 non-null  float64
#  29  month_cos                                  30672 non-null  float64
#  30  week_day_sin                               30672 non-null  float64
#  31  week_day_cos                               30672 non-null  float64
#  32  Nebulosité totale_lag_1                    30660 non-null  float64
#  33  Nebulosité totale_lag_2                    30648 non-null  float64
#  34  Nebulosité totale_lag_3                    30636 non-null  float64
#  35  Nebulosité totale_lag_4                    30624 non-null  float64
#  36  Nebulosité totale_lag_5                    30612 non-null  float64
#  37  Nebulosité totale_lag_6                    30600 non-null  float64
#  38  Nebulosité totale_lag_7                    30588 non-null  float64
# dtypes: bool(2), float64(31), int64(2), object(4)
# memory usage: 9.9+ MB

# %%
df_region = df_process.xs("Bretagne",level=DATACONFIG["Region"])

# %%
df_region.head()
# Out:
#                            Consommation brute électricité (MW) - RTE  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                                   121979.0
# 2013-01-02 00:00:00+01:00                                   153379.0
# 2013-01-03 00:00:00+01:00                                   151563.0
# 2013-01-04 00:00:00+01:00                                   150836.0
# 2013-01-05 00:00:00+01:00                                   137267.0
#
#                            Température (°C)  Nebulosité totale  \
# Date - Heure
# 2013-01-01 00:00:00+01:00          8.370833          73.229167
# 2013-01-02 00:00:00+01:00          9.453125          81.666667
# 2013-01-03 00:00:00+01:00         10.193750          98.750000
# 2013-01-04 00:00:00+01:00         10.051042         100.000000
# 2013-01-05 00:00:00+01:00          8.278125         100.000000
#
#                            Vitesse du vent moyen 10 mn   Humidité  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                     5.294792  77.468750
# 2013-01-02 00:00:00+01:00                     4.092708  83.187500
# 2013-01-03 00:00:00+01:00                     2.311458  86.927083
# 2013-01-04 00:00:00+01:00                     2.182292  88.343750
# 2013-01-05 00:00:00+01:00                     2.225000  95.937500
#
#                            Vitesse du vent en km/h  Température ressentie  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                 19.06125               5.420024
# 2013-01-02 00:00:00+01:00                 14.73375               7.273441
# 2013-01-03 00:00:00+01:00                  8.32125              10.193750
# 2013-01-04 00:00:00+01:00                  7.85625              10.051042
# 2013-01-05 00:00:00+01:00                  8.01000               6.982299
#
#                            Vitesse du vent en km/h  Température ressentie  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                 19.06125               5.420024
# 2013-01-02 00:00:00+01:00                 14.73375               7.273441
# 2013-01-03 00:00:00+01:00                  8.32125              10.193750
# 2013-01-04 00:00:00+01:00                  7.85625              10.051042
# 2013-01-05 00:00:00+01:00                  8.01000               6.982299
#
#                            saison  ...  month_cos  week_day_sin  week_day_cos  \
# Date - Heure                       ...
# 2013-01-01 00:00:00+01:00  winter  ...   0.866025      0.781831      0.623490
# 2013-01-02 00:00:00+01:00  winter  ...   0.866025      0.974928     -0.222521
# 2013-01-03 00:00:00+01:00  winter  ...   0.866025      0.433884     -0.900969
# 2013-01-04 00:00:00+01:00  winter  ...   0.866025     -0.433884     -0.900969
# 2013-01-05 00:00:00+01:00  winter  ...   0.866025     -0.974928     -0.222521
#
#                            Nebulosité totale_lag_1  Nebulosité totale_lag_2  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                      NaN                      NaN
# 2013-01-02 00:00:00+01:00                 8.437500                      NaN
# 2013-01-03 00:00:00+01:00                17.083333                25.520833
# 2013-01-04 00:00:00+01:00                 1.250000                18.333333
# 2013-01-05 00:00:00+01:00                 0.000000                 1.250000
#
#                            Nebulosité totale_lag_3 Nebulosité totale_lag_4  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                      NaN                     NaN
# 2013-01-02 00:00:00+01:00                      NaN                     NaN
# 2013-01-03 00:00:00+01:00                      NaN                     NaN
# 2013-01-04 00:00:00+01:00                26.770833                     NaN
# 2013-01-05 00:00:00+01:00                18.333333               26.770833
#
#                           Nebulosité totale_lag_5  Nebulosité totale_lag_6  \
# Date - Heure
# 2013-01-01 00:00:00+01:00                     NaN                      NaN
# 2013-01-02 00:00:00+01:00                     NaN                      NaN
# 2013-01-03 00:00:00+01:00                     NaN                      NaN
# 2013-01-04 00:00:00+01:00                     NaN                      NaN
# 2013-01-05 00:00:00+01:00                     NaN                      NaN
#
#                           Nebulosité totale_lag_7
# Date - Heure
# 2013-01-01 00:00:00+01:00                     NaN
# 2013-01-02 00:00:00+01:00                     NaN
# 2013-01-03 00:00:00+01:00                     NaN
# 2013-01-04 00:00:00+01:00                     NaN
# 2013-01-05 00:00:00+01:00                     NaN
#
# [5 rows x 39 columns]
